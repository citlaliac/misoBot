# %%
##########GET FILES AND DICTS##########

#open misoOutput
misoOutput = open("misoOutput.txt", "w")

#read songFile
misoSongTest = open("misoSongTest.txt","r")

#make a clean file to put the clean text into
cleanSongText = open("cleanSongText.txt", "w")

#open or make misoDict
#misoDict = open("misoDictionary.ipynb", "r")
misoDict = { 
    #pronouns
		"she" : "he",
        "she's" : "he's",
        "shes" : "he's",
		"her" : "his",
		"hers" : "his",
		"herself" : "himself",
    #babys
		"babygirl" : "babyboy",
    #female to male
		"girl" : "boy",
		"girls" : "boys",
        "lady" : "guy",
        "ladies" : "guys",
        "gal" : "lad",
        "gals" : "lads",
        "female" : "male",
        "females" : "males",
        "chic" : "dude",
        "chics" : "dudes",
        "chick" : "dude",
        "chicks" : "dudes",
        "woman" : "man",
        "women" :  "men",
        "sister" : "brother",
        "sisters" : "brothers",
        "mom" : "dad",
        "daughter" : "son",
        "daughters" : "sons",
        "miss" : "mr",
        "ms" : "mr",
        "mrs" : "mr",
        "mizz" : "mr",
        #"my girl" : "my bro"
        #"my girls" : "my bros",
    #derogatory female to derogatory male
        "bitch" : "dude",
        "bitches" : "dudes",
        "ho" : "manhoe",
        "hoe" : "manhoe",
        "hoes" : "manhoes",
        "ho's" : "manhoes",
        "slut" : "slutboi",
        "sluts" : "slutboiss",
        "skank" : "skank",
        "skanks" : "skanks",
        "whore" : "whore",
        "whores" : "whores",
        "milf" : "dilf",
        "milfs" : "dilfs",
        "pussy" : "dick",
        "pussies" : "dicks",
    #body parts
        "pussy" : "weeny",
        "vagina" : "penis",
        "boobs" : "chest",
        "titties" : "pecks"}

#for word in misoDict:
#    mTest = misoDict[word]
#    print (mTest)

# %%
##########APPLY LOGIC##########

#look at each word and print it into the new file
for line in misoSongTest:
    for word in line.split():          
#if word doesnt match dict word
        if (word not in misoDict):
            misoOutput.write(word + " ")
        #else, the word does match
        elif (word in misoDict):
            #then replace that word and write it to the new file
            misoOutput.write(misoDict[word] + " ")
                
                    
#close files
misoSongTest.close() 
misoOutput.close() 
cleanSongText.close()

# %%
##########GET IMPORTS (would go first)##########
#import re, string, unicodedata
#import nltk

#import nltk
#nltk.download('punkt')

#from nltk import word_tokenize, sent_tokenize
#from nltk import punkt


##########CLEAN TEXT (would go before logic)##########

#preprocess the lyrics
#for line in misoSongTest:
#    for word in line.split():
#        cleanSongText.write(word + " ")
        
#misoWords = nltk.word_tokenize(cleanSongText)
#print(misoWords)
        

#remove non_ascii, make all lowercase, remove punctuation
#def remove_non_ascii(words):
#    """Remove non-ASCII characters from list of tokenized words"""
#    new_words = []
#    for word in words:
#        new_word = unicodedata.normalize('NFKD', word).encode('ascii', 'ignore').decode('utf-8', 'ignore')
#        new_words.append(new_word)
#    return new_words

#def to_lowercase(words):
#    """Convert all characters to lowercase from list of tokenized words"""
#    new_words = []
#    for word in words:
#        new_word = word.lower()
#        new_words.append(new_word)
#    return new_words

#def remove_punctuation(words):
#    """Remove punctuation from list of tokenized words"""
#    new_words = []
#    for word in words:
#        new_word = re.sub(r'[^\w\s]', '', word)
#        if new_word != '':
#            new_words.append(new_word)
#    return new_words
